# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# coordinates
a=[1,2,3]
b=[1,2,3]

# %%
# test graph
plt.plot(a,b)
plt.xlabel('number')
plt.ylabel('number')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# plotting an equation
llimit=10    # upper limit of function
ulimit=50    # lower limit of function
c=np.linspace(llimit,ulimit) # format np.linspace(point1,point2,....)
d=x**3
plt.xlabel('points')
plt.ylabel('cubes')
plt.title('plotting equations')
plt.plot(c,d)
plt.show()

# %%
# finding area under the graph
from sympy import *
x,y,z = symbols('x y z')
d=x**3
area=integrate(d,(x,10,50))
print(area,'sq units')
# Out:
# 1560000 sq units
